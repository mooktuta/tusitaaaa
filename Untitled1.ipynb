# %% [markdown]
# <a href="https://colab.research.google.com/github/mooktuta/tusitaaaa/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Book:

    def __init__(
        self,
        book_isbn,
        book_title,
        book_author,
        price,
        category_id,
        sud_category_id,
        shelf_locati,
        stock_qty,
    ):
        self.book_isbn = book_isbn
        self.book_title = book_title
        self.book_author = book_author
        self.price = price
        self.category_id = category_id
        self.sud_category_id = sud_category_id
        self.shelf_locati = shelf_locati
        self.stock_qty = stock_qty

# %%
# ข้อมูลรหัสหนังสือต่อจากกวาง ล่าขุมทรัพย์ - juju
# ล่าขุมทรัพย์สุดขอบฟ้า (รวม 80 เล่ม)
book287 = Book(
    book_isbn = "B55020501",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 1",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book288 = Book(
    book_isbn = "B55020502",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 2",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book289 = Book(
    book_isbn = "B55020503",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 3",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book290 = Book(
    book_isbn = "B55020504",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 4",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book291 = Book(
    book_isbn = "B55020505",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 5",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book292 = Book(
    book_isbn = "B55020506",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 6",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book293 = Book(
    book_isbn = "B55020507",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 7",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book294 = Book(
    book_isbn = "B55020508",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 8",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book295 = Book(
    book_isbn = "B55020509",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 9",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book296 = Book(
    book_isbn = "B55020510",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 10",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book297 = Book(
    book_isbn = "B55020511",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 11",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book298 = Book(
    book_isbn = "B55020512",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 12",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book299 = Book(
    book_isbn = "B55020513",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 13",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book300 = Book(
    book_isbn = "B55020514",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 14",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book301 = Book(
    book_isbn = "B55020515",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 15",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book302 = Book(
    book_isbn = "B55020516",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 16",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book303 = Book(
    book_isbn = "B55020517",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 17",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book304 = Book(
    book_isbn = "B55020518",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 18",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book305 = Book(
    book_isbn = "B55020519",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 19",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book306 = Book(
    book_isbn = "B55020520",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 20",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book307 = Book(
    book_isbn = "B55020521",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 21",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book308 = Book(
    book_isbn = "B55020522",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 22",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book309 = Book(
    book_isbn = "B55020523",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 23",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book310 = Book(
    book_isbn = "B55020524",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 24",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book311 = Book(
    book_isbn = "B55020525",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 25",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book312 = Book(
    book_isbn = "B55020526",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 26",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book313 = Book(
    book_isbn = "B55020527",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 27",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book314 = Book(
    book_isbn = "B55020528",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 28",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book315 = Book(
    book_isbn = "B55020529",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 29",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book316 = Book(
    book_isbn = "B55020530",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 30",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book317 = Book(
    book_isbn = "B55020531",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 31",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book318 = Book(
    book_isbn = "B55020532",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 32",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book319 = Book(
    book_isbn = "B55020533",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 33",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book320 = Book(
    book_isbn = "B55020534",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 34",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book321 = Book(
    book_isbn = "B55020535",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 35",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book322 = Book(
    book_isbn = "B55020536",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 36",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book323 = Book(
    book_isbn = "B55020537",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 37",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book324 = Book(
    book_isbn = "B55020538",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 38",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book325 = Book(
    book_isbn = "B55020539",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 39",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book326 = Book(
    book_isbn = "B55020540",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 40",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book327 = Book(
    book_isbn = "B55020541",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 41",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book328 = Book(
    book_isbn = "B55020542",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 42",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book329 = Book(
    book_isbn = "B55020543",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 43",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book330 = Book(
    book_isbn = "B55020544",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 44",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book331 = Book(
    book_isbn = "B55020545",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 45",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book332 = Book(
    book_isbn = "B55020546",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 46",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book333 = Book(
    book_isbn = "B55020547",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 47",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book334 = Book(
    book_isbn = "B55020548",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 48",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book335 = Book(
    book_isbn = "B55020549",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 49",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book336 = Book(
    book_isbn = "B55020550",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 50",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book337 = Book(
    book_isbn = "B55020551",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 51",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book338 = Book(
    book_isbn = "B55020552",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 52",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book339 = Book(
    book_isbn = "B55020553",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 53",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book340 = Book(
    book_isbn = "B55020554",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 54",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book341 = Book(
    book_isbn = "B55020555",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 55",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book342 = Book(
    book_isbn = "B55020556",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 56",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book343 = Book(
    book_isbn = "B55020557",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 57",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book344 = Book(
    book_isbn = "B55020558",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 58",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book345 = Book(
    book_isbn = "B55020559",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 59",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book346 = Book(
    book_isbn = "B55020560",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 60",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book347 = Book(
    book_isbn = "B55020561",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 61",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book348 = Book(
    book_isbn = "B55020562",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 62",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book349 = Book(
    book_isbn = "B55020563",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 63",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book350 = Book(
    book_isbn = "B55020564",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 64",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book351 = Book(
    book_isbn = "B55020565",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 65",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book352 = Book(
    book_isbn = "B55020566",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 66",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book353 = Book(
    book_isbn = "B55020567",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 67",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book354 = Book(
    book_isbn = "B55020568",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 68",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book355 = Book(
    book_isbn = "B55020569",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 69",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book356 = Book(
    book_isbn = "B55020570",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 70",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book357 = Book(
    book_isbn = "B55020571",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 71",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book358 = Book(
    book_isbn = "B55020572",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 72",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book359 = Book(
    book_isbn = "B55020573",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 73",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book360 = Book(
    book_isbn = "B55020574",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 74",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book361 = Book(
    book_isbn = "B55020575",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 75",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book362 = Book(
    book_isbn = "B55020576",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 76",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book363 = Book(
    book_isbn = "B55020577",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 77",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book364 = Book(
    book_isbn = "B55020578",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 78",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book365 = Book(
    book_isbn = "B55020579",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 79",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book366 = Book(
    book_isbn = "B55020580",
    book_title = "ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 80",
    book_author = "Gomdori co.",
    price = "155 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "C-02",
    stock_qty = "1",
)


# ลูปสร้างตัวแปร book287 (เล่ม 1) ถึง book366 (เล่ม 80) และพิมพ์ข้อมูล
for index in range(287, 367):
    volume_num = index - 286  # book287 = เล่ม 1, book288 = เล่ม 2 ...
    isbn = f"B550205{volume_num:02d}"
    title = f"ล่าขุมทรัพย์สุดขอบฟ้า เล่ม {volume_num}"

    # สร้าง Object
    book = Book(
        book_isbn=isbn,
        book_title=title,
        book_author="Gomdori co.",
        price="155 บาท/เล่ม",
        category_id="02",
        sud_category_id="05",
        shelf_locati="C-02",
        stock_qty="1",
    )

    # ประกาศเป็นตัวแปรชื่อ book287 ถึง book366 ให้อัตโนมัติ
    globals()[f"book{index}"] = book

    # พิมพ์ข้อมูล
    print("รหัส ISBN:", book.book_isbn)
    print("ชื่อเรื่อง:", book.book_title)
    print("ผู้แต่ง:", book.book_author)
    print("ราคา:", book.price)
    print("รหัสหมวดหมู่:", book.category_id)
    print("รหัสแนวเรื่อง:", book.sud_category_id)
    print("ตำแหน่งชั้นวาง:", book.shelf_locati)
    print("จำนวนคงเหลือ:", book.stock_qty)
    print("-" * 30)
# Out:
# รหัส ISBN: B55020501
# ชื่อเรื่อง: ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 1
# ผู้แต่ง: Gomdori co.
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B55020502
# ชื่อเรื่อง: ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 2
# ผู้แต่ง: Gomdori co.
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B55020503
# ชื่อเรื่อง: ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 3
# ผู้แต่ง: Gomdori co.
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B55020504
# ชื่อเรื่อง: ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 4
# ผู้แต่ง: Gomdori co.
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B55020505
# ชื่อเรื่อง: ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 5
# ผู้แต่ง: Gomdori co.
# ...

# %%
# โคนัน ทั้งหมด107เล่ม
book367 = Book(
    book_isbn = "B50010201",
    book_title = "โคนัน / Detective Conan เล่ม 1",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book368 = Book(
    book_isbn = "B50010202",
    book_title = "โคนัน / Detective Conan เล่ม 2",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book369 = Book(
    book_isbn = "B50010203",
    book_title = "โคนัน / Detective Conan เล่ม 3",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book370 = Book(
    book_isbn = "B50010204",
    book_title = "โคนัน / Detective Conan เล่ม 4",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book371 = Book(
    book_isbn = "B50010205",
    book_title = "โคนัน / Detective Conan เล่ม 5",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book372 = Book(
    book_isbn = "B50010206",
    book_title = "โคนัน / Detective Conan เล่ม 6",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book373 = Book(
    book_isbn = "B50010207",
    book_title = "โคนัน / Detective Conan เล่ม 7",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book374 = Book(
    book_isbn = "B50010208",
    book_title = "โคนัน / Detective Conan เล่ม 8",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book375 = Book(
    book_isbn = "B50010209",
    book_title = "โคนัน / Detective Conan เล่ม 9",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book376 = Book(
    book_isbn = "B50010210",
    book_title = "โคนัน / Detective Conan เล่ม 10",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book377 = Book(
    book_isbn = "B50010211",
    book_title = "โคนัน / Detective Conan เล่ม 11",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book378 = Book(
    book_isbn = "B50010212",
    book_title = "โคนัน / Detective Conan เล่ม 12",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book379 = Book(
    book_isbn = "B50010213",
    book_title = "โคนัน / Detective Conan เล่ม 13",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book380 = Book(
    book_isbn = "B50010214",
    book_title = "โคนัน / Detective Conan เล่ม 14",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book381 = Book(
    book_isbn = "B50010215",
    book_title = "โคนัน / Detective Conan เล่ม 15",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book382 = Book(
    book_isbn = "B50010216",
    book_title = "โคนัน / Detective Conan เล่ม 16",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book383 = Book(
    book_isbn = "B50010217",
    book_title = "โคนัน / Detective Conan เล่ม 17",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book384 = Book(
    book_isbn = "B50010218",
    book_title = "โคนัน / Detective Conan เล่ม 18",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book385 = Book(
    book_isbn = "B50010219",
    book_title = "โคนัน / Detective Conan เล่ม 19",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book386 = Book(
    book_isbn = "B50010220",
    book_title = "โคนัน / Detective Conan เล่ม 20",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book387 = Book(
    book_isbn = "B50010221",
    book_title = "โคนัน / Detective Conan เล่ม 21",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book388 = Book(
    book_isbn = "B50010222",
    book_title = "โคนัน / Detective Conan เล่ม 22",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book389 = Book(
    book_isbn = "B50010223",
    book_title = "โคนัน / Detective Conan เล่ม 23",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book390 = Book(
    book_isbn = "B50010224",
    book_title = "โคนัน / Detective Conan เล่ม 24",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book391 = Book(
    book_isbn = "B50010225",
    book_title = "โคนัน / Detective Conan เล่ม 25",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book392 = Book(
    book_isbn = "B50010226",
    book_title = "โคนัน / Detective Conan เล่ม 26",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book393 = Book(
    book_isbn = "B50010227",
    book_title = "โคนัน / Detective Conan เล่ม 27",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book394 = Book(
    book_isbn = "B50010228",
    book_title = "โคนัน / Detective Conan เล่ม 28",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book395 = Book(
    book_isbn = "B50010229",
    book_title = "โคนัน / Detective Conan เล่ม 29",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book396 = Book(
    book_isbn = "B50010230",
    book_title = "โคนัน / Detective Conan เล่ม 30",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book397 = Book(
    book_isbn = "B50010231",
    book_title = "โคนัน / Detective Conan เล่ม 31",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book398 = Book(
    book_isbn = "B50010232",
    book_title = "โคนัน / Detective Conan เล่ม 32",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book399 = Book(
    book_isbn = "B50010233",
    book_title = "โคนัน / Detective Conan เล่ม 33",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book400 = Book(
    book_isbn = "B50010234",
    book_title = "โคนัน / Detective Conan เล่ม 34",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book401 = Book(
    book_isbn = "B50010235",
    book_title = "โคนัน / Detective Conan เล่ม 35",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book402 = Book(
    book_isbn = "B50010236",
    book_title = "โคนัน / Detective Conan เล่ม 36",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book403 = Book(
    book_isbn = "B50010237",
    book_title = "โคนัน / Detective Conan เล่ม 37",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book404 = Book(
    book_isbn = "B50010238",
    book_title = "โคนัน / Detective Conan เล่ม 38",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book405 = Book(
    book_isbn = "B50010239",
    book_title = "โคนัน / Detective Conan เล่ม 39",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book406 = Book(
    book_isbn = "B50010240",
    book_title = "โคนัน / Detective Conan เล่ม 40",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book407 = Book(
    book_isbn = "B50010241",
    book_title = "โคนัน / Detective Conan เล่ม 41",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book408 = Book(
    book_isbn = "B50010242",
    book_title = "โคนัน / Detective Conan เล่ม 42",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book409 = Book(
    book_isbn = "B50010243",
    book_title = "โคนัน / Detective Conan เล่ม 43",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book410 = Book(
    book_isbn = "B50010244",
    book_title = "โคนัน / Detective Conan เล่ม 44",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book411 = Book(
    book_isbn = "B50010245",
    book_title = "โคนัน / Detective Conan เล่ม 45",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book412 = Book(
    book_isbn = "B50010246",
    book_title = "โคนัน / Detective Conan เล่ม 46",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book413 = Book(
    book_isbn = "B50010247",
    book_title = "โคนัน / Detective Conan เล่ม 47",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book414 = Book(
    book_isbn = "B50010248",
    book_title = "โคนัน / Detective Conan เล่ม 48",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book415 = Book(
    book_isbn = "B50010249",
    book_title = "โคนัน / Detective Conan เล่ม 49",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book416 = Book(
    book_isbn = "B50010250",
    book_title = "โคนัน / Detective Conan เล่ม 50",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book417 = Book(
    book_isbn = "B50010251",
    book_title = "โคนัน / Detective Conan เล่ม 51",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book418 = Book(
    book_isbn = "B50010252",
    book_title = "โคนัน / Detective Conan เล่ม 52",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book419 = Book(
    book_isbn = "B50010253",
    book_title = "โคนัน / Detective Conan เล่ม 53",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book420 = Book(
    book_isbn = "B50010254",
    book_title = "โคนัน / Detective Conan เล่ม 54",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book421 = Book(
    book_isbn = "B50010255",
    book_title = "โคนัน / Detective Conan เล่ม 55",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book422 = Book(
    book_isbn = "B50010256",
    book_title = "โคนัน / Detective Conan เล่ม 56",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book423 = Book(
    book_isbn = "B50010257",
    book_title = "โคนัน / Detective Conan เล่ม 57",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book424 = Book(
    book_isbn = "B50010258",
    book_title = "โคนัน / Detective Conan เล่ม 58",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book425 = Book(
    book_isbn = "B50010259",
    book_title = "โคนัน / Detective Conan เล่ม 59",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book426 = Book(
    book_isbn = "B50010260",
    book_title = "โคนัน / Detective Conan เล่ม 60",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book427 = Book(
    book_isbn = "B50010261",
    book_title = "โคนัน / Detective Conan เล่ม 61",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book428 = Book(
    book_isbn = "B50010262",
    book_title = "โคนัน / Detective Conan เล่ม 62",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book429 = Book(
    book_isbn = "B50010263",
    book_title = "โคนัน / Detective Conan เล่ม 63",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book430 = Book(
    book_isbn = "B50010264",
    book_title = "โคนัน / Detective Conan เล่ม 64",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book431 = Book(
    book_isbn = "B50010265",
    book_title = "โคนัน / Detective Conan เล่ม 65",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book432 = Book(
    book_isbn = "B50010266",
    book_title = "โคนัน / Detective Conan เล่ม 66",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book433 = Book(
    book_isbn = "B50010267",
    book_title = "โคนัน / Detective Conan เล่ม 67",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book434 = Book(
    book_isbn = "B50010268",
    book_title = "โคนัน / Detective Conan เล่ม 68",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book435 = Book(
    book_isbn = "B50010269",
    book_title = "โคนัน / Detective Conan เล่ม 69",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book436 = Book(
    book_isbn = "B50010270",
    book_title = "โคนัน / Detective Conan เล่ม 70",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book437 = Book(
    book_isbn = "B50010271",
    book_title = "โคนัน / Detective Conan เล่ม 71",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book438 = Book(
    book_isbn = "B50010272",
    book_title = "โคนัน / Detective Conan เล่ม 72",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book439 = Book(
    book_isbn = "B50010273",
    book_title = "โคนัน / Detective Conan เล่ม 73",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book440 = Book(
    book_isbn = "B50010274",
    book_title = "โคนัน / Detective Conan เล่ม 74",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book441 = Book(
    book_isbn = "B50010275",
    book_title = "โคนัน / Detective Conan เล่ม 75",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book442 = Book(
    book_isbn = "B50010276",
    book_title = "โคนัน / Detective Conan เล่ม 76",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book443 = Book(
    book_isbn = "B50010277",
    book_title = "โคนัน / Detective Conan เล่ม 77",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book444 = Book(
    book_isbn = "B50010278",
    book_title = "โคนัน / Detective Conan เล่ม 78",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book445 = Book(
    book_isbn = "B50010279",
    book_title = "โคนัน / Detective Conan เล่ม 79",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book446 = Book(
    book_isbn = "B50010280",
    book_title = "โคนัน / Detective Conan เล่ม 80",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book447 = Book(
    book_isbn = "B50010281",
    book_title = "โคนัน / Detective Conan เล่ม 81",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book448 = Book(
    book_isbn = "B50010282",
    book_title = "โคนัน / Detective Conan เล่ม 82",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book449 = Book(
    book_isbn = "B50010283",
    book_title = "โคนัน / Detective Conan เล่ม 83",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book450 = Book(
    book_isbn = "B50010284",
    book_title = "โคนัน / Detective Conan เล่ม 84",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book451 = Book(
    book_isbn = "B50010285",
    book_title = "โคนัน / Detective Conan เล่ม 85",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book452 = Book(
    book_isbn = "B50010286",
    book_title = "โคนัน / Detective Conan เล่ม 86",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book453 = Book(
    book_isbn = "B50010287",
    book_title = "โคนัน / Detective Conan เล่ม 87",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book454 = Book(
    book_isbn = "B50010288",
    book_title = "โคนัน / Detective Conan เล่ม 88",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book455 = Book(
    book_isbn = "B50010289",
    book_title = "โคนัน / Detective Conan เล่ม 89",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book456 = Book(
    book_isbn = "B50010290",
    book_title = "โคนัน / Detective Conan เล่ม 90",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book457 = Book(
    book_isbn = "B50010291",
    book_title = "โคนัน / Detective Conan เล่ม 91",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book458 = Book(
    book_isbn = "B50010292",
    book_title = "โคนัน / Detective Conan เล่ม 92",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book459 = Book(
    book_isbn = "B50010293",
    book_title = "โคนัน / Detective Conan เล่ม 93",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book460 = Book(
    book_isbn = "B50010294",
    book_title = "โคนัน / Detective Conan เล่ม 94",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book461 = Book(
    book_isbn = "B50010295",
    book_title = "โคนัน / Detective Conan เล่ม 95",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book462 = Book(
    book_isbn = "B50010296",
    book_title = "โคนัน / Detective Conan เล่ม 96",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book463 = Book(
    book_isbn = "B50010297",
    book_title = "โคนัน / Detective Conan เล่ม 97",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book464 = Book(
    book_isbn = "B50010298",
    book_title = "โคนัน / Detective Conan เล่ม 98",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book465 = Book(
    book_isbn = "B50010299",
    book_title = "โคนัน / Detective Conan เล่ม 99",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book466 = Book(
    book_isbn = "B500102100",
    book_title = "โคนัน / Detective Conan เล่ม 100",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book467 = Book(
    book_isbn = "B500102101",
    book_title = "โคนัน / Detective Conan เล่ม 101",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book468 = Book(
    book_isbn = "B500102102",
    book_title = "โคนัน / Detective Conan เล่ม 102",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book469 = Book(
    book_isbn = "B500102103",
    book_title = "โคนัน / Detective Conan เล่ม 103",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book470 = Book(
    book_isbn = "B500102104",
    book_title = "โคนัน / Detective Conan เล่ม 104",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book471 = Book(
    book_isbn = "B500102105",
    book_title = "โคนัน / Detective Conan เล่ม 105",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book472 = Book(
    book_isbn = "B500102106",
    book_title = "โคนัน / Detective Conan เล่ม 106",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)

book473 = Book(
    book_isbn = "B500102107",
    book_title = "โคนัน / Detective Conan เล่ม 107",
    book_author = "Gosho Aoyama",
    price = "155 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "02",
    shelf_locati = "C-02",
    stock_qty = "1",
)


# ลูปสร้างตัวแปร book367 (เล่ม 1) ถึง book473 (เล่ม 107) และพิมพ์ข้อมูล
for index in range(367, 474):
    volume_num = index - 366  # book367 = เล่ม 1, book368 = เล่ม 2 ...

    # กำหนดฟอร์แมต ISBN (เล่ม 1-99 เติม 0 นำหน้า 2 หลัก, เล่ม 100+ ใช้เลข 3 หลัก)
    if volume_num < 100:
        isbn = f"B500102{volume_num:02d}"
    else:
        isbn = f"B500102{volume_num}"

    title = f"โคนัน / Detective Conan เล่ม {volume_num}"

    # สร้าง Object
    book = Book(
        book_isbn=isbn,
        book_title=title,
        book_author="Gosho Aoyama",
        price="155 บาท/เล่ม",
        category_id="01",
        sud_category_id="02",
        shelf_locati="C-02",
        stock_qty="1",
    )

    # ประกาศเป็นตัวแปรชื่อ book367 ถึง book473 ให้อัตโนมัติ
    globals()[f"book{index}"] = book

    # พิมพ์ข้อมูล
    print("รหัส ISBN:", book.book_isbn)
    print("ชื่อเรื่อง:", book.book_title)
    print("ผู้แต่ง:", book.book_author)
    print("ราคา:", book.price)
    print("รหัสหมวดหมู่:", book.category_id)
    print("รหัสแนวเรื่อง:", book.sud_category_id)
    print("ตำแหน่งชั้นวาง:", book.shelf_locati)
    print("จำนวนคงเหลือ:", book.stock_qty)
    print("-" * 30)
# Out:
# รหัส ISBN: B50010201
# ชื่อเรื่อง: โคนัน / Detective Conan เล่ม 1
# ผู้แต่ง: Gosho Aoyama
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 02
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B50010202
# ชื่อเรื่อง: โคนัน / Detective Conan เล่ม 2
# ผู้แต่ง: Gosho Aoyama
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 02
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B50010203
# ชื่อเรื่อง: โคนัน / Detective Conan เล่ม 3
# ผู้แต่ง: Gosho Aoyama
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 02
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B50010204
# ชื่อเรื่อง: โคนัน / Detective Conan เล่ม 4
# ผู้แต่ง: Gosho Aoyama
# ราคา: 155 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 02
# ตำแหน่งชั้นวาง: C-02
# จำนวนคงเหลือ: 1
# ------------------------------
# รหัส ISBN: B50010205
# ชื่อเรื่อง: โคนัน / Detective Conan เล่ม 5
# ผู้แต่ง: Gosho Aoyama
# ...

# %%
# คุกกี้รัน เอาชีวิตรอด ทั้งหมด40เล่ม
book474 = Book(
    book_isbn = "B55020501",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 1",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book475 = Book(
    book_isbn = "B55020502",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 2",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book476 = Book(
    book_isbn = "B55020503",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 3",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book477 = Book(
    book_isbn = "B55020504",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 4",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book478 = Book(
    book_isbn = "B55020505",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 5",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book479 = Book(
    book_isbn = "B55020506",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 6",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book480 = Book(
    book_isbn = "B55020507",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 7",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book481 = Book(
    book_isbn = "B55020508",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 8",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book482 = Book(
    book_isbn = "B55020509",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 9",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book483 = Book(
    book_isbn = "B55020510",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 10",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book484 = Book(
    book_isbn = "B55020511",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 11",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book485 = Book(
    book_isbn = "B55020512",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 12",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book486 = Book(
    book_isbn = "B55020513",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 13",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book487 = Book(
    book_isbn = "B55020514",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 14",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book488 = Book(
    book_isbn = "B55020515",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 15",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book489 = Book(
    book_isbn = "B55020516",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 16",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book490 = Book(
    book_isbn = "B55020517",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 17",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book491 = Book(
    book_isbn = "B55020518",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 18",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book492 = Book(
    book_isbn = "B55020519",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 19",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book493 = Book(
    book_isbn = "B55020520",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 20",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book494 = Book(
    book_isbn = "B55020521",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 21",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book495 = Book(
    book_isbn = "B55020522",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 22",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book496 = Book(
    book_isbn = "B55020523",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 23",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book497 = Book(
    book_isbn = "B55020524",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 24",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book498 = Book(
    book_isbn = "B55020525",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 25",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book499 = Book(
    book_isbn = "B55020526",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 26",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book500 = Book(
    book_isbn = "B55020527",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 27",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book501 = Book(
    book_isbn = "B55020528",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 28",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book502 = Book(
    book_isbn = "B55020529",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 29",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book503 = Book(
    book_isbn = "B55020530",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 30",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book504 = Book(
    book_isbn = "B55020531",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 31",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book505 = Book(
    book_isbn = "B55020532",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 32",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book506 = Book(
    book_isbn = "B55020533",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 33",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book507 = Book(
    book_isbn = "B55020534",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 34",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book508 = Book(
    book_isbn = "B55020535",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 35",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book509 = Book(
    book_isbn = "B55020536",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 36",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book510 = Book(
    book_isbn = "B55020537",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 37",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book511 = Book(
    book_isbn = "B55020538",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 38",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book512 = Book(
    book_isbn = "B55020539",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 39",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)

book513 = Book(
    book_isbn = "B55020540",
    book_title = "คุกกี้รัน เอาชีวิตรอด เล่ม 40",
    book_author = "Kim Kang-gyun",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "05",
    shelf_locati = "E-05",
    stock_qty = "1",
)


# ลูปสร้างตัวแปร book474 (เล่ม 1) ถึง book513 (เล่ม 40) พร้อมแสดงผล
for vol_num in range(1, 41):
    var_index = 473 + vol_num  # book474 ถึง book513
    isbn = f"B550205{vol_num:02d}"  # เติม 0 ด้านหน้าหากเป็นเลขหลักเดียว

    book = Book(
        book_isbn=isbn,
        book_title=f"คุกกี้รัน เอาชีวิตรอด เล่ม {vol_num}",
        book_author="Kim Kang-gyun",
        price="165 บาท/เล่ม",
        category_id="02",
        sud_category_id="05",
        shelf_locati="E-05",
        stock_qty="1",
    )

    # กำหนดชื่อตัวแปรแบบไดนามิก
    globals()[f"book{var_index}"] = book

    # คำสั่งแสดงผลข้อมูลแต่ละเล่มออกทางหน้าจอ
    print(f"--- book{var_index} ---")
    print(f"รหัส ISBN: {book.book_isbn}")
    print(f"ชื่อเรื่อง: {book.book_title}")
    print(f"ผู้แต่ง: {book.book_author}")
    print(f"ราคา: {book.price}")
    print(f"รหัสหมวดหมู่: {book.category_id}")
    print(f"รหัสแนวเรื่อง: {book.sud_category_id}")
    print(f"ตำแหน่งชั้นวาง: {book.shelf_locati}")
    print(f"จำนวนคงเหลือ: {book.stock_qty}")
    print("-" * 30)
# Out:
# --- book474 ---
# รหัส ISBN: B55020501
# ชื่อเรื่อง: คุกกี้รัน เอาชีวิตรอด เล่ม 1
# ผู้แต่ง: Kim Kang-gyun
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: E-05
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book475 ---
# รหัส ISBN: B55020502
# ชื่อเรื่อง: คุกกี้รัน เอาชีวิตรอด เล่ม 2
# ผู้แต่ง: Kim Kang-gyun
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: E-05
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book476 ---
# รหัส ISBN: B55020503
# ชื่อเรื่อง: คุกกี้รัน เอาชีวิตรอด เล่ม 3
# ผู้แต่ง: Kim Kang-gyun
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: E-05
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book477 ---
# รหัส ISBN: B55020504
# ชื่อเรื่อง: คุกกี้รัน เอาชีวิตรอด เล่ม 4
# ผู้แต่ง: Kim Kang-gyun
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 05
# ตำแหน่งชั้นวาง: E-05
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book478 ---
# ...

# %%
# คุกกี้รัน ผจญภัย ทั้งหมด49เล่ม
book514 = Book(
    book_isbn = "B56020601",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 1",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book515 = Book(
    book_isbn = "B56020602",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 2",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book516 = Book(
    book_isbn = "B56020603",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 3",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book517 = Book(
    book_isbn = "B56020604",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 4",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book518 = Book(
    book_isbn = "B56020605",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 5",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book519 = Book(
    book_isbn = "B56020606",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 6",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book520 = Book(
    book_isbn = "B56020607",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 7",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book521 = Book(
    book_isbn = "B56020608",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 8",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book522 = Book(
    book_isbn = "B56020609",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 9",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book523 = Book(
    book_isbn = "B56020610",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 10",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book524 = Book(
    book_isbn = "B56020611",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 11",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book525 = Book(
    book_isbn = "B56020612",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 12",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book526 = Book(
    book_isbn = "B56020613",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 13",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book527 = Book(
    book_isbn = "B56020614",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 14",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book528 = Book(
    book_isbn = "B56020615",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 15",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book529 = Book(
    book_isbn = "B56020616",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 16",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book530 = Book(
    book_isbn = "B56020617",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 17",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book531 = Book(
    book_isbn = "B56020618",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 18",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book532 = Book(
    book_isbn = "B56020619",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 19",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book533 = Book(
    book_isbn = "B56020620",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 20",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book534 = Book(
    book_isbn = "B56020621",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 21",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book535 = Book(
    book_isbn = "B56020622",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 22",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book536 = Book(
    book_isbn = "B56020623",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 23",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book537 = Book(
    book_isbn = "B56020624",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 24",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book538 = Book(
    book_isbn = "B56020625",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 25",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book539 = Book(
    book_isbn = "B56020626",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 26",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book540 = Book(
    book_isbn = "B56020627",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 27",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book541 = Book(
    book_isbn = "B56020628",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 28",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book542 = Book(
    book_isbn = "B56020629",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 29",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book543 = Book(
    book_isbn = "B56020630",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 30",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book544 = Book(
    book_isbn = "B56020631",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 31",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book545 = Book(
    book_isbn = "B56020632",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 32",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book546 = Book(
    book_isbn = "B56020633",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 33",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book547 = Book(
    book_isbn = "B56020634",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 34",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book548 = Book(
    book_isbn = "B56020635",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 35",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book549 = Book(
    book_isbn = "B56020636",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 36",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book550 = Book(
    book_isbn = "B56020637",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 37",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book551 = Book(
    book_isbn = "B56020638",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 38",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book552 = Book(
    book_isbn = "B56020639",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 39",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book553 = Book(
    book_isbn = "B56020640",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 40",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book554 = Book(
    book_isbn = "B56020641",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 41",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book555 = Book(
    book_isbn = "B56020642",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 42",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book556 = Book(
    book_isbn = "B56020643",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 43",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book557 = Book(
    book_isbn = "B56020644",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 44",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book558 = Book(
    book_isbn = "B56020645",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 45",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book559 = Book(
    book_isbn = "B56020646",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 46",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book560 = Book(
    book_isbn = "B56020647",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 47",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book561 = Book(
    book_isbn = "B56020648",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 48",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)

book562 = Book(
    book_isbn = "B56020649",
    book_title = "คุกกี้รัน ผจญภัย เล่ม 49",
    book_author = "Song Do Su",
    price = "165 บาท/เล่ม",
    category_id = "02",
    sud_category_id = "06",
    shelf_locati = "E-06",
    stock_qty = "1",
)


# ลูปสร้างตัวแปร book514 (เล่ม 1) ถึง book562 (เล่ม 49) พร้อมแสดงผล
for vol_num in range(1, 50):
    var_index = 513 + vol_num  # book514 ถึง book562
    isbn = f"B560206{vol_num:02d}"  # เติม 0 ด้านหน้าหากเป็นเลขหลักเดียว (01-49)

    book = Book(
        book_isbn=isbn,
        book_title=f"คุกกี้รัน ผจญภัย เล่ม {vol_num}",
        book_author="Song Do Su",
        price="165 บาท/เล่ม",
        category_id="02",
        sud_category_id="06",
        shelf_locati="E-06",
        stock_qty="1",
    )

    # กำหนดชื่อตัวแปรแบบไดนามิก
    globals()[f"book{var_index}"] = book

    # คำสั่งแสดงผลข้อมูลแต่ละเล่มออกทางหน้าจอ
    print(f"--- book{var_index} ---")
    print(f"รหัส ISBN: {book.book_isbn}")
    print(f"ชื่อเรื่อง: {book.book_title}")
    print(f"ผู้แต่ง: {book.book_author}")
    print(f"ราคา: {book.price}")
    print(f"รหัสหมวดหมู่: {book.category_id}")
    print(f"รหัสแนวเรื่อง: {book.sud_category_id}")
    print(f"ตำแหน่งชั้นวาง: {book.shelf_locati}")
    print(f"จำนวนคงเหลือ: {book.stock_qty}")
    print("-" * 30)
# Out:
# --- book514 ---
# รหัส ISBN: B56020601
# ชื่อเรื่อง: คุกกี้รัน ผจญภัย เล่ม 1
# ผู้แต่ง: Song Do Su
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 06
# ตำแหน่งชั้นวาง: E-06
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book515 ---
# รหัส ISBN: B56020602
# ชื่อเรื่อง: คุกกี้รัน ผจญภัย เล่ม 2
# ผู้แต่ง: Song Do Su
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 06
# ตำแหน่งชั้นวาง: E-06
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book516 ---
# รหัส ISBN: B56020603
# ชื่อเรื่อง: คุกกี้รัน ผจญภัย เล่ม 3
# ผู้แต่ง: Song Do Su
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 06
# ตำแหน่งชั้นวาง: E-06
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book517 ---
# รหัส ISBN: B56020604
# ชื่อเรื่อง: คุกกี้รัน ผจญภัย เล่ม 4
# ผู้แต่ง: Song Do Su
# ราคา: 165 บาท/เล่ม
# รหัสหมวดหมู่: 02
# รหัสแนวเรื่อง: 06
# ตำแหน่งชั้นวาง: E-06
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book518 ---
# รหัส ISBN: B56020605
# ...

# %%
# Spy x Family ทั้งหมด16เล่ม
book563 = Book(
    book_isbn = "B57010101",
    book_title = "Spy x Family เล่ม 1",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book564 = Book(
    book_isbn = "B57010102",
    book_title = "Spy x Family เล่ม 2",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book565 = Book(
    book_isbn = "B57010103",
    book_title = "Spy x Family เล่ม 3",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book566 = Book(
    book_isbn = "B57010104",
    book_title = "Spy x Family เล่ม 4",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book567 = Book(
    book_isbn = "B57010105",
    book_title = "Spy x Family เล่ม 5",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book568 = Book(
    book_isbn = "B57010106",
    book_title = "Spy x Family เล่ม 6",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book569 = Book(
    book_isbn = "B57010107",
    book_title = "Spy x Family เล่ม 7",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book570 = Book(
    book_isbn = "B57010108",
    book_title = "Spy x Family เล่ม 8",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book571 = Book(
    book_isbn = "B57010109",
    book_title = "Spy x Family เล่ม 9",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book572 = Book(
    book_isbn = "B57010110",
    book_title = "Spy x Family เล่ม 10",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book573 = Book(
    book_isbn = "B57010111",
    book_title = "Spy x Family เล่ม 11",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book574 = Book(
    book_isbn = "B57010112",
    book_title = "Spy x Family เล่ม 12",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book575 = Book(
    book_isbn = "B57010113",
    book_title = "Spy x Family เล่ม 13",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book576 = Book(
    book_isbn = "B57010114",
    book_title = "Spy x Family เล่ม 14",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book577 = Book(
    book_isbn = "B57010115",
    book_title = "Spy x Family เล่ม 15",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book578 = Book(
    book_isbn = "B57010116",
    book_title = "Spy x Family เล่ม 16",
    book_author = "Tatsuya Endo",
    price = "95 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)


# ลูปสร้างตัวแปร book563 (เล่ม 1) ถึง book578 (เล่ม 16) พร้อมแสดงผล
for vol_num in range(1, 17):
    var_index = 562 + vol_num  # book563 ถึง book578
    isbn = f"B570101{vol_num:02d}"  # เติม 0 ด้านหน้าหากเป็นเลขหลักเดียว (01-16)

    book = Book(
        book_isbn=isbn,
        book_title=f"Spy x Family เล่ม {vol_num}",
        book_author="Tatsuya Endo",
        price="95 บาท/เล่ม",
        category_id="01",
        sud_category_id="01",
        shelf_locati="A-01",
        stock_qty="1",
    )

    # กำหนดชื่อตัวแปรแบบไดนามิก
    globals()[f"book{var_index}"] = book

    # คำสั่งแสดงผลข้อมูลแต่ละเล่มออกทางหน้าจอ
    print(f"--- book{var_index} ---")
    print(f"รหัส ISBN: {book.book_isbn}")
    print(f"ชื่อเรื่อง: {book.book_title}")
    print(f"ผู้แต่ง: {book.book_author}")
    print(f"ราคา: {book.price}")
    print(f"รหัสหมวดหมู่: {book.category_id}")
    print(f"รหัสแนวเรื่อง: {book.sud_category_id}")
    print(f"ตำแหน่งชั้นวาง: {book.shelf_locati}")
    print(f"จำนวนคงเหลือ: {book.stock_qty}")
    print("-" * 30)
# Out:
# --- book563 ---
# รหัส ISBN: B57010101
# ชื่อเรื่อง: Spy x Family เล่ม 1
# ผู้แต่ง: Tatsuya Endo
# ราคา: 95 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book564 ---
# รหัส ISBN: B57010102
# ชื่อเรื่อง: Spy x Family เล่ม 2
# ผู้แต่ง: Tatsuya Endo
# ราคา: 95 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book565 ---
# รหัส ISBN: B57010103
# ชื่อเรื่อง: Spy x Family เล่ม 3
# ผู้แต่ง: Tatsuya Endo
# ราคา: 95 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book566 ---
# รหัส ISBN: B57010104
# ชื่อเรื่อง: Spy x Family เล่ม 4
# ผู้แต่ง: Tatsuya Endo
# ราคา: 95 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book567 ---
# รหัส ISBN: B57010105
# ...

# %%
# Jujutsu Kaisen(หมาเวทย์ผนึกมาร) ทั้งหมด28เล่ม
book579 = Book(
    book_isbn = "B58010101",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 1",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book580 = Book(
    book_isbn = "B58010102",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 2",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book581 = Book(
    book_isbn = "B58010103",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 3",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book582 = Book(
    book_isbn = "B58010104",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 4",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book583 = Book(
    book_isbn = "B58010105",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 5",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book584 = Book(
    book_isbn = "B58010106",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 6",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book585 = Book(
    book_isbn = "B58010107",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 7",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book586 = Book(
    book_isbn = "B58010108",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 8",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book587 = Book(
    book_isbn = "B58010109",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 9",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book588 = Book(
    book_isbn = "B58010110",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 10",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book589 = Book(
    book_isbn = "B58010111",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 11",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book590 = Book(
    book_isbn = "B58010112",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 12",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book591 = Book(
    book_isbn = "B58010113",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 13",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book592 = Book(
    book_isbn = "B58010114",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 14",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book593 = Book(
    book_isbn = "B58010115",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 15",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book594 = Book(
    book_isbn = "B58010116",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 16",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book595 = Book(
    book_isbn = "B58010117",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 17",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book596 = Book(
    book_isbn = "B58010118",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 18",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book597 = Book(
    book_isbn = "B58010119",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 19",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book598 = Book(
    book_isbn = "B58010120",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 20",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book599 = Book(
    book_isbn = "B58010121",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 21",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book600 = Book(
    book_isbn = "B58010122",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 22",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book601 = Book(
    book_isbn = "B58010123",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 23",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book602 = Book(
    book_isbn = "B58010124",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 24",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book603 = Book(
    book_isbn = "B58010125",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 25",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book604 = Book(
    book_isbn = "B58010126",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 26",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book605 = Book(
    book_isbn = "B58010127",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 27",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)

book606 = Book(
    book_isbn = "B58010128",
    book_title = "มหาเวทย์ผนึกมาร เล่ม 28",
    book_author = "Gege Akutami",
    price = "90 บาท/เล่ม",
    category_id = "01",
    sud_category_id = "01",
    shelf_locati = "A-01",
    stock_qty = "1",
)


# ลูปสร้างตัวแปร book579 (เล่ม 1) ถึง book606 (เล่ม 28) พร้อมแสดงผล
for vol_num in range(1, 29):
    var_index = 578 + vol_num  # book579 ถึง book606
    isbn = f"B580101{vol_num:02d}"  # เติม 0 ด้านหน้าหากเป็นเลขหลักเดียว (01-28)

    book = Book(
        book_isbn=isbn,
        book_title=f"มหาเวทย์ผนึกมาร เล่ม {vol_num}",
        book_author="Gege Akutami",
        price="90 บาท/เล่ม",
        category_id="01",
        sud_category_id="01",
        shelf_locati="A-01",
        stock_qty="1",
    )

    # กำหนดชื่อตัวแปรแบบไดนามิก
    globals()[f"book{var_index}"] = book

    # คำสั่งแสดงผลข้อมูลแต่ละเล่มออกทางหน้าจอ
    print(f"--- book{var_index} ---")
    print(f"รหัส ISBN: {book.book_isbn}")
    print(f"ชื่อเรื่อง: {book.book_title}")
    print(f"ผู้แต่ง: {book.book_author}")
    print(f"ราคา: {book.price}")
    print(f"รหัสหมวดหมู่: {book.category_id}")
    print(f"รหัสแนวเรื่อง: {book.sud_category_id}")
    print(f"ตำแหน่งชั้นวาง: {book.shelf_locati}")
    print(f"จำนวนคงเหลือ: {book.stock_qty}")
    print("-" * 30)
# Out:
# --- book579 ---
# รหัส ISBN: B58010101
# ชื่อเรื่อง: มหาเวทย์ผนึกมาร เล่ม 1
# ผู้แต่ง: Gege Akutami
# ราคา: 90 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book580 ---
# รหัส ISBN: B58010102
# ชื่อเรื่อง: มหาเวทย์ผนึกมาร เล่ม 2
# ผู้แต่ง: Gege Akutami
# ราคา: 90 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book581 ---
# รหัส ISBN: B58010103
# ชื่อเรื่อง: มหาเวทย์ผนึกมาร เล่ม 3
# ผู้แต่ง: Gege Akutami
# ราคา: 90 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book582 ---
# รหัส ISBN: B58010104
# ชื่อเรื่อง: มหาเวทย์ผนึกมาร เล่ม 4
# ผู้แต่ง: Gege Akutami
# ราคา: 90 บาท/เล่ม
# รหัสหมวดหมู่: 01
# รหัสแนวเรื่อง: 01
# ตำแหน่งชั้นวาง: A-01
# จำนวนคงเหลือ: 1
# ------------------------------
# --- book583 ---
# รหัส ISBN: B58010105
# ...
